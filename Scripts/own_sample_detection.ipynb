# %%
# !pip install labelme tensorflow tensorflow-gpu opencv-python matplotlib albumentations
# Out:
# Collecting labelme
#   Using cached labelme-5.4.1-py3-none-any.whl
# Requirement already satisfied: tensorflow in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (2.16.1)
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-python in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (4.9.0.80)
# Requirement already satisfied: matplotlib in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (3.8.4)
# Collecting albumentations
#   Using cached albumentations-1.4.4-py3-none-any.whl (150 kB)
# Requirement already satisfied: Pillow>=2.8 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (10.3.0)
# Collecting qtpy!=1.11.2
#   Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting imgviz>=1.7.5
#   Using cached imgviz-1.7.5-py3-none-any.whl
# Collecting natsort>=7.1.0
#   Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: termcolor in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (2.4.0)
# Collecting PyQt5!=5.15.3,!=5.15.4
#   Using cached PyQt5-5.15.10-cp37-abi3-macosx_11_0_arm64.whl (6.6 MB)
# Collecting PyYAML
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Collecting onnxruntime!=1.16.0,>=1.14.1
#   Using cached onnxruntime-1.17.3-cp310-cp310-macosx_11_0_universal2.whl (14.8 MB)
# Collecting scikit-image
#   Using cached scikit_image-0.23.2-cp310-cp310-macosx_12_0_arm64.whl (13.3 MB)
# Requirement already satisfied: numpy in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (1.26.4)
# Requirement already satisfied: gdown in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (5.1.0)
# Requirement already satisfied: keras>=3.0.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: h5py>=3.10.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: six>=1.12.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: packaging in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (24.0)
# Requirement already satisfied: setuptools in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: python_version>"3.7" in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorflow-gpu) (0.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Collecting opencv-python-headless>=4.9.0
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-macosx_11_0_arm64.whl (35.4 MB)
# Collecting scikit-learn>=1.3.2
#   Using cached scikit_learn-1.4.2-cp310-cp310-macosx_12_0_arm64.whl (10.4 MB)
# Collecting scipy>=1.10.0
#   Using cached scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl (30.3 MB)
# Collecting pydantic>=2.6.4
#   Using cached pydantic-2.7.0-py3-none-any.whl (407 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: optree in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: namex in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.18.1
#   Using cached pydantic_core-2.18.1-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from PyQt5!=5.15.3,!=5.15.4->labelme) (5.15.13)
# Collecting PyQt5-sip<13,>=12.13
#   Using cached PyQt5_sip-12.13.0-cp310-cp310-macosx_10_9_universal2.whl (144 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from scikit-image->labelme) (2024.4.18)
# Collecting networkx>=2.8
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Collecting lazy-loader>=0.4
#   Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting imageio>=2.33
#   Using cached imageio-2.34.0-py3-none-any.whl (313 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.0-py3-none-any.whl (301 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from scikit-learn>=1.3.2->albumentations) (3.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.2)
# Requirement already satisfied: beautifulsoup4 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (4.12.3)
# Requirement already satisfied: tqdm in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (4.66.2)
# Requirement already satisfied: filelock in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (3.13.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from beautifulsoup4->gdown->labelme) (2.5)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.17.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/13/3pzxxwtd6cbdvdzq_lc6112r0000gn/T/pip-install-_m62r8yt/tensorflow-gpu_022857d31281414887364a2ec393f1e8/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: tensorflow-gpu, sympy, scipy, qtpy, PyYAML, PyQt5-sip, pydantic-core, opencv-python-headless, networkx, natsort, lazy-loader, joblib, imageio, humanfriendly, annotated-types, scikit-learn, scikit-image, PyQt5, pydantic, coloredlogs, onnxruntime, imgviz, albumentations, labelme
#   Running setup.py install for tensorflow-gpu ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for tensorflow-gpu did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/13/3pzxxwtd6cbdvdzq_lc6112r0000gn/T/pip-install-_m62r8yt/tensorflow-gpu_022857d31281414887364a2ec393f1e8/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import time
import uuid
import cv2
from matplotlib import pyplot as plt

# %%
IMAGES_PATH = os.path.join('data', 'images')
number_images = 30

# %%
cap = cv2.VideoCapture(0)
for imgnum in range(number_images):
    print('Collecting image {}'.format(imgnum))
    ret, frame = cap.read()
    img_name = os.path.join(IMAGES_PATH, f'str{(uuid.uuid1())}.jpg')
    cv2.imwrite(img_name, frame)
    cv2.imshow('frame', frame)
    time.sleep(0.5)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4
# Collecting image 5
# Collecting image 6
# Collecting image 7
# Collecting image 8
# Collecting image 9
# Collecting image 10
# Collecting image 11
# Collecting image 12
# Collecting image 13
# Collecting image 14
# Collecting image 15
# Collecting image 16
# Collecting image 17
# Collecting image 18
# Collecting image 19
# Collecting image 20
# Collecting image 21
# Collecting image 22
# Collecting image 23
# Collecting image 24
# Collecting image 25
# Collecting image 26
# Collecting image 27
# Collecting image 28
# Collecting image 29
# Der Kernel ist beim Ausführen von Code in der aktuellen Zelle oder einer vorherigen Zelle abgestürzt.
#
# Bitte überprüfen Sie den Code in der/den Zelle(n), um eine mögliche Fehlerursache zu identifizieren.
#
# Klicken Sie <a href='https://aka.ms/vscodeJupyterKernelCrash'>hier</a>, um weitere Informationen zu erhalten.
#
# Weitere Informationen finden Sie unter Jupyter <a href='command:jupyter.viewOutput'>Protokoll</a>.

# %%
# !pip install labelme
# Out:
# Collecting labelme
#   Using cached labelme-5.4.1-py3-none-any.whl
# Requirement already satisfied: gdown in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (5.1.0)
# Collecting PyYAML
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Collecting imgviz>=1.7.5
#   Using cached imgviz-1.7.5-py3-none-any.whl
# Collecting qtpy!=1.11.2
#   Using cached QtPy-2.4.1-py3-none-any.whl (93 kB)
# Collecting onnxruntime!=1.16.0,>=1.14.1
#   Using cached onnxruntime-1.17.3-cp310-cp310-macosx_11_0_universal2.whl (14.8 MB)
# Requirement already satisfied: termcolor in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (2.4.0)
# Requirement already satisfied: Pillow>=2.8 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (10.3.0)
# Collecting scikit-image
#   Using cached scikit_image-0.23.2-cp310-cp310-macosx_12_0_arm64.whl (13.3 MB)
# Collecting natsort>=7.1.0
#   Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from labelme) (3.8.4)
# Collecting PyQt5!=5.15.3,!=5.15.4
#   Using cached PyQt5-5.15.10-cp37-abi3-macosx_11_0_arm64.whl (6.6 MB)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: flatbuffers in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.3.25)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: packaging in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (24.0)
# Requirement already satisfied: protobuf in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from onnxruntime!=1.16.0,>=1.14.1->labelme) (4.25.3)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from PyQt5!=5.15.3,!=5.15.4->labelme) (5.15.13)
# Collecting PyQt5-sip<13,>=12.13
#   Using cached PyQt5_sip-12.13.0-cp310-cp310-macosx_10_9_universal2.whl (144 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (4.12.3)
# Requirement already satisfied: filelock in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (3.13.4)
# Requirement already satisfied: requests[socks] in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (2.31.0)
# Requirement already satisfied: tqdm in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from gdown->labelme) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (1.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from matplotlib->labelme) (4.51.0)
# Collecting lazy-loader>=0.4
#   Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting imageio>=2.33
#   Using cached imageio-2.34.0-py3-none-any.whl (313 kB)
# Collecting networkx>=2.8
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Collecting scipy>=1.9
#   Using cached scipy-1.13.0-cp310-cp310-macosx_12_0_arm64.whl (30.3 MB)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from scikit-image->labelme) (2024.4.18)
# Requirement already satisfied: six>=1.5 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from beautifulsoup4->gdown->labelme) (2.5)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests[socks]->gdown->labelme) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests[socks]->gdown->labelme) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests[socks]->gdown->labelme) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests[socks]->gdown->labelme) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from requests[socks]->gdown->labelme) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/riccardo/Desktop/Repositorys_Github/Python_Face_Recognition/face/lib/python3.10/site-packages (from sympy->onnxruntime!=1.16.0,>=1.14.1->labelme) (1.3.0)
# Installing collected packages: sympy, scipy, qtpy, PyYAML, PyQt5-sip, networkx, natsort, lazy-loader, imageio, humanfriendly, scikit-image, PyQt5, coloredlogs, onnxruntime, imgviz, labelme
# Successfully installed PyQt5-5.15.10 PyQt5-sip-12.13.0 PyYAML-6.0.1 coloredlogs-15.0.1 humanfriendly-10.0 imageio-2.34.0 imgviz-1.7.5 labelme-5.4.1 lazy-loader-0.4 natsort-8.4.0 networkx-3.3 onnxruntime-1.17.3 qtpy-2.4.1 scikit-image-0.23.2 scipy-1.13.0 sympy-1.12
#
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !labelme
# Out:
# 2024-04-21 13:52:54,702 [INFO   ] __init__:get_config:67- Loading config file from: /Users/riccardo/.labelmerc
